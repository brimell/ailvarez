# %%
import re
import urllib.parse
from logging import getLevelName, getLogger
from typing import Optional, Union

import requests
from cachecontrol import CacheControl

VERSION = "1.2.0"


class FotMob:
    BASE_URL = "https://www.fotmob.com/api"
    LOGGER = getLogger(__name__)

    def __init__(
        self, proxies: Optional[dict] = None, logging_level: Optional[str] = "WARNING"
    ) -> None:
        SESSION = requests.Session()
        if proxies:
            SESSION.proxies.update(proxies)
        CACHE_SESSION = CacheControl(SESSION)

        if logging_level:
            if logging_level.upper() in [
                "DEBUG",
                "INFO",
                "WARNING",
                "ERROR",
                "CRITICAL",
            ]:
                self.LOGGER.setLevel(getLevelName(logging_level.upper()))
            else:
                print(f"Logging level {logging_level} not recognized!")

        self.session = CACHE_SESSION
        self.matches_url = f"{self.BASE_URL}/matches?"
        self.leagues_url = f"{self.BASE_URL}/leagues?"
        self.teams_url = f"{self.BASE_URL}/teams?"
        self.player_url = f"{self.BASE_URL}/playerData?"
        self.match_details_url = f"{self.BASE_URL}/matchDetails?"
        self.search_url = f"{self.BASE_URL}/searchData?"
        self.tv_listing_url = f"{self.BASE_URL}/tvlisting?"
        self.tv_listings_url = f"{self.BASE_URL}/tvlistings?"
        self.fixtures_url = f"{self.BASE_URL}/fixtures?"

    def _check_date(self, date: str) -> Union[re.Match, None]:
        pattern = re.compile(r"(20\d{2})(\d{2})(\d{2})")
        return pattern.match(date)

    def _execute_query(self, url: str):
        response = self.session.get(url)
        response.raise_for_status()
        self.LOGGER.debug(response)
        return response.json()

    def get_matches_by_date(
        self, date: str, time_zone: str = "America/New_York"
    ) -> dict:
        if self._check_date(date) != None:
            url = f"{self.matches_url}date={date}"
            return self._execute_query(url)
        return {}

    def get_league(
        self,
        id: int,
        tab: str = "overview",
        type: str = "league",
    ):
        url = f"{self.leagues_url}id={id}&tab={tab}&type={type}"
        return self._execute_query(url)

    def get_team(
        self,
        id: int,
        tab: str = "overview",
        type: str = "league",
        time_zone: str = "America/New_York",
    ):
        url = f"{self.teams_url}id={id}&tab={tab}&type={type}"
        return self._execute_query(url)

    def get_player(self, id: int):
        url = f"{self.player_url}id={id}"
        return self._execute_query(url)

    def get_match_details(self, match_id: int):
        url = f"{self.match_details_url}matchId={match_id}"
        return self._execute_query(url)

    def get_match_tv_listing(self, match_id: int, country_code: str = "GB"):
        url = f"{self.tv_listing_url}matchId={match_id}&countryCode={country_code}"
        return self._execute_query(url)

    def get_tv_listings_country(self, country_code: str = "GB"):
        url = f"{self.tv_listings_url}countryCode={country_code}"
        return self._execute_query(url)

    def search(self, term: str, user_language: str = "en-GB,en"):
        searchterm = urllib.parse.quote_plus(term)
        url = f"{self.search_url}term={searchterm}&userLanguage={user_language}"
        return self._execute_query(url)

    def get_fixtures(self, id: str, season: str):
        url = f"{self.fixtures_url}id={id}&season={season}%2F2024"
        print(url)
        return self._execute_query(url)

# %%
Fot = FotMob()
Fot.get_fixtures("47", "2023")
# Out:
# https://www.fotmob.com/api/fixtures?id=47&season=2023%2F2024
# [{'id': '4193450',
#   'pageUrl': '/matches/burnley-vs-manchester-city/2ai7j8#4193450',
#   'opponent': {'id': '8191', 'name': 'Burnley', 'score': 0},
#   'home': {'id': '8191', 'name': 'Burnley', 'score': 0},
#   'away': {'id': '8456', 'name': 'Man City', 'score': 3},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-08-11T19:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '0 - 3',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193451',
#   'pageUrl': '/matches/arsenal-vs-nottingham-forest/3bf4p3#4193451',
#   'opponent': {'id': '9825', 'name': 'Arsenal', 'score': 2},
#   'home': {'id': '9825', 'name': 'Arsenal', 'score': 2},
#   'away': {'id': '10203', 'name': 'Nottm Forest', 'score': 1},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-08-12T12:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '2 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193452',
#   'pageUrl': '/matches/west-ham-united-vs-afc-bournemouth/2hfnrc#4193452',
#   'opponent': {'id': '8678', 'name': 'Bournemouth', 'score': 1},
#   'home': {'id': '8678', 'name': 'Bournemouth', 'score': 1},
#   'away': {'id': '8654', 'name': 'West Ham', 'score': 1},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-08-12T14:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '1 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193453',
#   'pageUrl': '/matches/luton-town-vs-brighton-hove-albion/2ug16v#4193453',
#   'opponent': {'id': '10204', 'name': 'Brighton', 'score': 4},
#   'home': {'id': '10204', 'name': 'Brighton', 'score': 4},
#   'away': {'id': '8346', 'name': 'Luton', 'score': 1},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-08-12T14:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '4 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193454',
#   'pageUrl': '/matches/everton-vs-fulham/2uevfp#4193454',
#   'opponent': {'id': '8668', 'name': 'Everton', 'score': 0},
#   'home': {'id': '8668', 'name': 'Everton', 'score': 0},
#   'away': {'id': '9879', 'name': 'Fulham', 'score': 1},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-08-12T14:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '0 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193455',
#   'pageUrl': '/matches/sheffield-united-vs-crystal-palace/2tph1s#4193455',
#   'opponent': {'id': '8657', 'name': 'Sheff Utd', 'score': 0},
#   'home': {'id': '8657', 'name': 'Sheff Utd', 'score': 0},
#   'away': {'id': '9826', 'name': 'Crystal Palace', 'score': 1},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-08-12T14:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '0 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193456',
#   'pageUrl': '/matches/aston-villa-vs-newcastle-united/3h9v0m#4193456',
#   'opponent': {'id': '10261', 'name': 'Newcastle', 'score': 5},
#   'home': {'id': '10261', 'name': 'Newcastle', 'score': 5},
#   'away': {'id': '10252', 'name': 'Aston Villa', 'score': 1},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-08-12T16:30:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '5 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193457',
#   'pageUrl': '/matches/tottenham-hotspur-vs-brentford/2u5c8b#4193457',
#   'opponent': {'id': '9937', 'name': 'Brentford', 'score': 2},
#   'home': {'id': '9937', 'name': 'Brentford', 'score': 2},
#   'away': {'id': '8586', 'name': 'Tottenham', 'score': 2},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-08-13T13:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '2 - 2',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193458',
#   'pageUrl': '/matches/chelsea-vs-liverpool/2f3vr7#4193458',
#   'opponent': {'id': '8455', 'name': 'Chelsea', 'score': 1},
#   'home': {'id': '8455', 'name': 'Chelsea', 'score': 1},
#   'away': {'id': '8650', 'name': 'Liverpool', 'score': 1},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-08-13T15:30:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '1 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193459',
#   'pageUrl': '/matches/wolverhampton-wanderers-vs-manchester-united/2xx4sz#4193459',
#   'opponent': {'id': '10260', 'name': 'Man United', 'score': 1},
#   'home': {'id': '10260', 'name': 'Man United', 'score': 1},
#   'away': {'id': '8602', 'name': 'Wolves', 'score': 0},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-08-14T19:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '1 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193476',
#   'pageUrl': '/matches/sheffield-united-vs-nottingham-forest/2xwbqn#4193476',
#   'opponent': {'id': '10203', 'name': 'Nottm Forest', 'score': 2},
#   'home': {'id': '10203', 'name': 'Nottm Forest', 'score': 2},
#   'away': {'id': '8657', 'name': 'Sheff Utd', 'score': 1},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-08-18T18:45:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '2 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193472',
#   'pageUrl': '/matches/fulham-vs-brentford/38wlut#4193472',
#   'opponent': {'id': '9879', 'name': 'Fulham', 'score': 0},
#   'home': {'id': '9879', 'name': 'Fulham', 'score': 0},
#   'away': {'id': '9937', 'name': 'Brentford', 'score': 3},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-08-19T14:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '0 - 3',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193473',
#   'pageUrl': '/matches/liverpool-vs-afc-bournemouth/2he69q#4193473',
#   'opponent': {'id': '8650', 'name': 'Liverpool', 'score': 3},
#   'home': {'id': '8650', 'name': 'Liverpool', 'score': 3},
#   'away': {'id': '8678', 'name': 'Bournemouth', 'score': 1},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-08-19T14:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '3 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193479',
#   'pageUrl': '/matches/wolverhampton-wanderers-vs-brighton-hove-albion/2xaiyv#4193479',
#   'opponent': {'id': '8602', 'name': 'Wolves', 'score': 1},
#   'home': {'id': '8602', 'name': 'Wolves', 'score': 1},
#   'away': {'id': '10204', 'name': 'Brighton', 'score': 4},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-08-19T14:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '1 - 4',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193477',
#   'pageUrl': '/matches/tottenham-hotspur-vs-manchester-united/2xqo0r#4193477',
#   'opponent': {'id': '8586', 'name': 'Tottenham', 'score': 2},
#   'home': {'id': '8586', 'name': 'Tottenham', 'score': 2},
#   'away': {'id': '10260', 'name': 'Man United', 'score': 0},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-08-19T16:30:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '2 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193475',
#   'pageUrl': '/matches/manchester-city-vs-newcastle-united/2waqez#4193475',
#   'opponent': {'id': '8456', 'name': 'Man City', 'score': 1},
#   'home': {'id': '8456', 'name': 'Man City', 'score': 1},
#   'away': {'id': '10261', 'name': 'Newcastle', 'score': 0},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-08-19T19:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '1 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193470',
#   'pageUrl': '/matches/everton-vs-aston-villa/2ykmb4#4193470',
#   'opponent': {'id': '10252', 'name': 'Aston Villa', 'score': 4},
#   'home': {'id': '10252', 'name': 'Aston Villa', 'score': 4},
#   'away': {'id': '8668', 'name': 'Everton', 'score': 0},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-08-20T13:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '4 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193478',
#   'pageUrl': '/matches/chelsea-vs-west-ham-united/2f5ck5#4193478',
#   'opponent': {'id': '8654', 'name': 'West Ham', 'score': 3},
#   'home': {'id': '8654', 'name': 'West Ham', 'score': 3},
#   'away': {'id': '8455', 'name': 'Chelsea', 'score': 1},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-08-20T15:30:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '3 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193471',
#   'pageUrl': '/matches/arsenal-vs-crystal-palace/36ytc8#4193471',
#   'opponent': {'id': '9826', 'name': 'Crystal Palace', 'score': 0},
#   'home': {'id': '9826', 'name': 'Crystal Palace', 'score': 0},
#   'away': {'id': '9825', 'name': 'Arsenal', 'score': 1},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-08-21T19:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '0 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193485',
#   'pageUrl': '/matches/luton-town-vs-chelsea/2c1euw#4193485',
#   'opponent': {'id': '8455', 'name': 'Chelsea', 'score': 3},
#   'home': {'id': '8455', 'name': 'Chelsea', 'score': 3},
#   'away': {'id': '8346', 'name': 'Luton', 'score': 0},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-08-25T19:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '3 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193480',
#   'pageUrl': '/matches/tottenham-hotspur-vs-afc-bournemouth/2gqg4e#4193480',
#   'opponent': {'id': '8678', 'name': 'Bournemouth', 'score': 0},
#   'home': {'id': '8678', 'name': 'Bournemouth', 'score': 0},
#   'away': {'id': '8586', 'name': 'Tottenham', 'score': 2},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-08-26T11:30:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '0 - 2',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193481',
#   'pageUrl': '/matches/arsenal-vs-fulham/37l643#4193481',
#   'opponent': {'id': '9825', 'name': 'Arsenal', 'score': 2},
#   'home': {'id': '9825', 'name': 'Arsenal', 'score': 2},
#   'away': {'id': '9879', 'name': 'Fulham', 'score': 2},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-08-26T14:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '2 - 2',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193482',
#   'pageUrl': '/matches/crystal-palace-vs-brentford/38a4jj#4193482',
#   'opponent': {'id': '9937', 'name': 'Brentford', 'score': 1},
#   'home': {'id': '9937', 'name': 'Brentford', 'score': 1},
#   'away': {'id': '9826', 'name': 'Crystal Palace', 'score': 1},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-08-26T14:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '1 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193486',
#   'pageUrl': '/matches/wolverhampton-wanderers-vs-everton/2gso21#4193486',
#   'opponent': {'id': '8668', 'name': 'Everton', 'score': 0},
#   'home': {'id': '8668', 'name': 'Everton', 'score': 0},
#   'away': {'id': '8602', 'name': 'Wolves', 'score': 1},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-08-26T14:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '0 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193487',
#   'pageUrl': '/matches/nottingham-forest-vs-manchester-united/3gnwkc#4193487',
#   'opponent': {'id': '10260', 'name': 'Man United', 'score': 3},
#   'home': {'id': '10260', 'name': 'Man United', 'score': 3},
#   'away': {'id': '10203', 'name': 'Nottm Forest', 'score': 2},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-08-26T14:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '3 - 2',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193483',
#   'pageUrl': '/matches/west-ham-united-vs-brighton-hove-albion/2xvimt#4193483',
#   'opponent': {'id': '10204', 'name': 'Brighton', 'score': 1},
#   'home': {'id': '10204', 'name': 'Brighton', 'score': 1},
#   'away': {'id': '8654', 'name': 'West Ham', 'score': 3},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-08-26T16:30:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '1 - 3',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193484',
#   'pageUrl': '/matches/burnley-vs-aston-villa/2t9lxd#4193484',
#   'opponent': {'id': '8191', 'name': 'Burnley', 'score': 1},
#   'home': {'id': '8191', 'name': 'Burnley', 'score': 1},
#   'away': {'id': '10252', 'name': 'Aston Villa', 'score': 3},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-08-27T13:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '1 - 3',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193489',
#   'pageUrl': '/matches/manchester-city-vs-sheffield-united/2f6tdi#4193489',
#   'opponent': {'id': '8657', 'name': 'Sheff Utd', 'score': 1},
#   'home': {'id': '8657', 'name': 'Sheff Utd', 'score': 1},
#   'away': {'id': '8456', 'name': 'Man City', 'score': 2},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-08-27T13:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '1 - 2',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193488',
#   'pageUrl': '/matches/liverpool-vs-newcastle-united/2ygyxm#4193488',
#   'opponent': {'id': '10261', 'name': 'Newcastle', 'score': 1},
#   'home': {'id': '10261', 'name': 'Newcastle', 'score': 1},
#   'away': {'id': '8650', 'name': 'Liverpool', 'score': 2},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-08-27T15:30:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '1 - 2',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193497',
#   'pageUrl': '/matches/luton-town-vs-west-ham-united/2e1i5e#4193497',
#   'opponent': {'id': '8346', 'name': 'Luton', 'score': 1},
#   'home': {'id': '8346', 'name': 'Luton', 'score': 1},
#   'away': {'id': '8654', 'name': 'West Ham', 'score': 2},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-09-01T19:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '1 - 2',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193499',
#   'pageUrl': '/matches/sheffield-united-vs-everton/2hd25j#4193499',
#   'opponent': {'id': '8657', 'name': 'Sheff Utd', 'score': 2},
#   'home': {'id': '8657', 'name': 'Sheff Utd', 'score': 2},
#   'away': {'id': '8668', 'name': 'Everton', 'score': 2},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-09-02T11:30:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '2 - 2',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193491',
#   'pageUrl': '/matches/afc-bournemouth-vs-brentford/2v5yfp#4193491',
#   'opponent': {'id': '9937', 'name': 'Brentford', 'score': 2},
#   'home': {'id': '9937', 'name': 'Brentford', 'score': 2},
#   'away': {'id': '8678', 'name': 'Bournemouth', 'score': 2},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-09-02T14:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '2 - 2',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193493',
#   'pageUrl': '/matches/burnley-vs-tottenham-hotspur/2bss1j#4193493',
#   'opponent': {'id': '8191', 'name': 'Burnley', 'score': 2},
#   'home': {'id': '8191', 'name': 'Burnley', 'score': 2},
#   'away': {'id': '8586', 'name': 'Tottenham', 'score': 5},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-09-02T14:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '2 - 5',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193494',
#   'pageUrl': '/matches/chelsea-vs-nottingham-forest/2vn3ne#4193494',
#   'opponent': {'id': '8455', 'name': 'Chelsea', 'score': 0},
#   'home': {'id': '8455', 'name': 'Chelsea', 'score': 0},
#   'away': {'id': '10203', 'name': 'Nottm Forest', 'score': 1},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-09-02T14:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '0 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193498',
#   'pageUrl': '/matches/manchester-city-vs-fulham/2s32rr#4193498',
#   'opponent': {'id': '8456', 'name': 'Man City', 'score': 5},
#   'home': {'id': '8456', 'name': 'Man City', 'score': 5},
#   'away': {'id': '9879', 'name': 'Fulham', 'score': 1},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-09-02T14:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '5 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193492',
#   'pageUrl': '/matches/brighton-hove-albion-vs-newcastle-united/3gos5a#4193492',
#   'opponent': {'id': '10204', 'name': 'Brighton', 'score': 3},
#   'home': {'id': '10204', 'name': 'Brighton', 'score': 3},
#   'away': {'id': '10261', 'name': 'Newcastle', 'score': 1},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-09-02T16:30:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '3 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193495',
#   'pageUrl': '/matches/wolverhampton-wanderers-vs-crystal-palace/2t3pt4#4193495',
#   'opponent': {'id': '9826', 'name': 'Crystal Palace', 'score': 3},
#   'home': {'id': '9826', 'name': 'Crystal Palace', 'score': 3},
#   'away': {'id': '8602', 'name': 'Wolves', 'score': 2},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-09-03T13:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '3 - 2',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193496',
#   'pageUrl': '/matches/liverpool-vs-aston-villa/2ydbmv#4193496',
#   'opponent': {'id': '8650', 'name': 'Liverpool', 'score': 3},
#   'home': {'id': '8650', 'name': 'Liverpool', 'score': 3},
#   'away': {'id': '10252', 'name': 'Aston Villa', 'score': 0},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-09-03T13:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '3 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193490',
#   'pageUrl': '/matches/arsenal-vs-manchester-united/3c3mu0#4193490',
#   'opponent': {'id': '9825', 'name': 'Arsenal', 'score': 3},
#   'home': {'id': '9825', 'name': 'Arsenal', 'score': 3},
#   'away': {'id': '10260', 'name': 'Man United', 'score': 1},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-09-03T15:30:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '3 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193509',
#   'pageUrl': '/matches/wolverhampton-wanderers-vs-liverpool/2gm0as#4193509',
#   'opponent': {'id': '8602', 'name': 'Wolves', 'score': 1},
#   'home': {'id': '8602', 'name': 'Wolves', 'score': 1},
#   'away': {'id': '8650', 'name': 'Liverpool', 'score': 3},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-09-16T11:30:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '1 - 3',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193501',
#   'pageUrl': '/matches/crystal-palace-vs-aston-villa/3c0md7#4193501',
#   'opponent': {'id': '10252', 'name': 'Aston Villa', 'score': 3},
#   'home': {'id': '10252', 'name': 'Aston Villa', 'score': 3},
#   'away': {'id': '9826', 'name': 'Crystal Palace', 'score': 1},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-09-16T14:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '3 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193503',
#   'pageUrl': '/matches/luton-town-vs-fulham/2qvz6o#4193503',
#   'opponent': {'id': '9879', 'name': 'Fulham', 'score': 1},
#   'home': {'id': '9879', 'name': 'Fulham', 'score': 1},
#   'away': {'id': '8346', 'name': 'Luton', 'score': 0},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-09-16T14:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '1 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193504',
#   'pageUrl': '/matches/brighton-hove-albion-vs-manchester-united/3goccs#4193504',
#   'opponent': {'id': '10260', 'name': 'Man United', 'score': 1},
#   'home': {'id': '10260', 'name': 'Man United', 'score': 1},
#   'away': {'id': '10204', 'name': 'Brighton', 'score': 3},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-09-16T14:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '1 - 3',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193507',
#   'pageUrl': '/matches/tottenham-hotspur-vs-sheffield-united/2gioiz#4193507',
#   'opponent': {'id': '8586', 'name': 'Tottenham', 'score': 2},
#   'home': {'id': '8586', 'name': 'Tottenham', 'score': 2},
#   'away': {'id': '8657', 'name': 'Sheff Utd', 'score': 1},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-09-16T14:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '2 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193508',
#   'pageUrl': '/matches/manchester-city-vs-west-ham-united/2f5prf#4193508',
#   'opponent': {'id': '8654', 'name': 'West Ham', 'score': 1},
#   'home': {'id': '8654', 'name': 'West Ham', 'score': 1},
#   'away': {'id': '8456', 'name': 'Man City', 'score': 3},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-09-16T14:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '1 - 3',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193505',
#   'pageUrl': '/matches/brentford-vs-newcastle-united/3dgf4m#4193505',
#   'opponent': {'id': '10261', 'name': 'Newcastle', 'score': 1},
#   'home': {'id': '10261', 'name': 'Newcastle', 'score': 1},
#   'away': {'id': '9937', 'name': 'Brentford', 'score': 0},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-09-16T16:30:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '1 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193500',
#   'pageUrl': '/matches/chelsea-vs-afc-bournemouth/2fe5n5#4193500',
#   'opponent': {'id': '8678', 'name': 'Bournemouth', 'score': 0},
#   'home': {'id': '8678', 'name': 'Bournemouth', 'score': 0},
#   'away': {'id': '8455', 'name': 'Chelsea', 'score': 0},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-09-17T13:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '0 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193502',
#   'pageUrl': '/matches/everton-vs-arsenal/2ttfpg#4193502',
#   'opponent': {'id': '8668', 'name': 'Everton', 'score': 0},
#   'home': {'id': '8668', 'name': 'Everton', 'score': 0},
#   'away': {'id': '9825', 'name': 'Arsenal', 'score': 1},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-09-17T15:30:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '0 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193506',
#   'pageUrl': '/matches/burnley-vs-nottingham-forest/2sq9j2#4193506',
#   'opponent': {'id': '10203', 'name': 'Nottm Forest', 'score': 1},
#   'home': {'id': '10203', 'name': 'Nottm Forest', 'score': 1},
#   'away': {'id': '8191', 'name': 'Burnley', 'score': 1},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-09-18T18:45:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '1 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193515',
#   'pageUrl': '/matches/crystal-palace-vs-fulham/37llbg#4193515',
#   'opponent': {'id': '9826', 'name': 'Crystal Palace', 'score': 0},
#   'home': {'id': '9826', 'name': 'Crystal Palace', 'score': 0},
#   'away': {'id': '9879', 'name': 'Fulham', 'score': 0},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-09-23T14:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '0 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193517',
#   'pageUrl': '/matches/luton-town-vs-wolverhampton-wanderers/2dil18#4193517',
#   'opponent': {'id': '8346', 'name': 'Luton', 'score': 1},
#   'home': {'id': '8346', 'name': 'Luton', 'score': 1},
#   'away': {'id': '8602', 'name': 'Wolves', 'score': 1},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-09-23T14:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '1 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193518',
#   'pageUrl': '/matches/manchester-city-vs-nottingham-forest/2vni1q#4193518',
#   'opponent': {'id': '8456', 'name': 'Man City', 'score': 2},
#   'home': {'id': '8456', 'name': 'Man City', 'score': 2},
#   'away': {'id': '10203', 'name': 'Nottm Forest', 'score': 0},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-09-23T14:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '2 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193511',
#   'pageUrl': '/matches/everton-vs-brentford/2v1yu4#4193511',
#   'opponent': {'id': '9937', 'name': 'Brentford', 'score': 1},
#   'home': {'id': '9937', 'name': 'Brentford', 'score': 1},
#   'away': {'id': '8668', 'name': 'Everton', 'score': 3},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-09-23T16:30:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '1 - 3',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193513',
#   'pageUrl': '/matches/burnley-vs-manchester-united/2tcrst#4193513',
#   'opponent': {'id': '8191', 'name': 'Burnley', 'score': 0},
#   'home': {'id': '8191', 'name': 'Burnley', 'score': 0},
#   'away': {'id': '10260', 'name': 'Man United', 'score': 1},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-09-23T19:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '0 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193510',
#   'pageUrl': '/matches/tottenham-hotspur-vs-arsenal/2sx06r#4193510',
#   'opponent': {'id': '9825', 'name': 'Arsenal', 'score': 2},
#   'home': {'id': '9825', 'name': 'Arsenal', 'score': 2},
#   'away': {'id': '8586', 'name': 'Tottenham', 'score': 2},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-09-24T13:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '2 - 2',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193512',
#   'pageUrl': '/matches/afc-bournemouth-vs-brighton-hove-albion/2y583t#4193512',
#   'opponent': {'id': '10204', 'name': 'Brighton', 'score': 3},
#   'home': {'id': '10204', 'name': 'Brighton', 'score': 3},
#   'away': {'id': '8678', 'name': 'Bournemouth', 'score': 1},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-09-24T13:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '3 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193514',
#   'pageUrl': '/matches/chelsea-vs-aston-villa/2w6q11#4193514',
#   'opponent': {'id': '8455', 'name': 'Chelsea', 'score': 0},
#   'home': {'id': '8455', 'name': 'Chelsea', 'score': 0},
#   'away': {'id': '10252', 'name': 'Aston Villa', 'score': 1},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-09-24T13:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '0 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193516',
#   'pageUrl': '/matches/liverpool-vs-west-ham-united/2h59kq#4193516',
#   'opponent': {'id': '8650', 'name': 'Liverpool', 'score': 3},
#   'home': {'id': '8650', 'name': 'Liverpool', 'score': 3},
#   'away': {'id': '8654', 'name': 'West Ham', 'score': 1},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-09-24T13:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '3 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193519',
#   'pageUrl': '/matches/sheffield-united-vs-newcastle-united/2yjt3q#4193519',
#   'opponent': {'id': '8657', 'name': 'Sheff Utd', 'score': 0},
#   'home': {'id': '8657', 'name': 'Sheff Utd', 'score': 0},
#   'away': {'id': '10261', 'name': 'Newcastle', 'score': 8},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-09-24T15:30:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '0 - 8',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193521',
#   'pageUrl': '/matches/brighton-hove-albion-vs-aston-villa/3gku1s#4193521',
#   'opponent': {'id': '10252', 'name': 'Aston Villa', 'score': 6},
#   'home': {'id': '10252', 'name': 'Aston Villa', 'score': 6},
#   'away': {'id': '10204', 'name': 'Brighton', 'score': 1},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-09-30T11:30:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '6 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193520',
#   'pageUrl': '/matches/afc-bournemouth-vs-arsenal/2txefx#4193520',
#   'opponent': {'id': '8678', 'name': 'Bournemouth', 'score': 0},
#   'home': {'id': '8678', 'name': 'Bournemouth', 'score': 0},
#   'away': {'id': '9825', 'name': 'Arsenal', 'score': 4},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-09-30T14:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '0 - 4',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193522',
#   'pageUrl': '/matches/luton-town-vs-everton/2e6lvt#4193522',
#   'opponent': {'id': '8668', 'name': 'Everton', 'score': 1},
#   'home': {'id': '8668', 'name': 'Everton', 'score': 1},
#   'away': {'id': '8346', 'name': 'Luton', 'score': 2},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-09-30T14:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '1 - 2',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193524',
#   'pageUrl': '/matches/crystal-palace-vs-manchester-united/3c42bz#4193524',
#   'opponent': {'id': '10260', 'name': 'Man United', 'score': 0},
#   'home': {'id': '10260', 'name': 'Man United', 'score': 0},
#   'away': {'id': '9826', 'name': 'Crystal Palace', 'score': 1},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-09-30T14:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '0 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193525',
#   'pageUrl': '/matches/burnley-vs-newcastle-united/2td61d#4193525',
#   'opponent': {'id': '10261', 'name': 'Newcastle', 'score': 2},
#   'home': {'id': '10261', 'name': 'Newcastle', 'score': 2},
#   'away': {'id': '8191', 'name': 'Burnley', 'score': 0},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-09-30T14:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '2 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193528',
#   'pageUrl': '/matches/west-ham-united-vs-sheffield-united/2h7v29#4193528',
#   'opponent': {'id': '8654', 'name': 'West Ham', 'score': 2},
#   'home': {'id': '8654', 'name': 'West Ham', 'score': 2},
#   'away': {'id': '8657', 'name': 'Sheff Utd', 'score': 0},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-09-30T14:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '2 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193529',
#   'pageUrl': '/matches/manchester-city-vs-wolverhampton-wanderers/2emo8d#4193529',
#   'opponent': {'id': '8602', 'name': 'Wolves', 'score': 2},
#   'home': {'id': '8602', 'name': 'Wolves', 'score': 2},
#   'away': {'id': '8456', 'name': 'Man City', 'score': 1},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-09-30T14:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '2 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193527',
#   'pageUrl': '/matches/tottenham-hotspur-vs-liverpool/2gg3ek#4193527',
#   'opponent': {'id': '8586', 'name': 'Tottenham', 'score': 2},
#   'home': {'id': '8586', 'name': 'Tottenham', 'score': 2},
#   'away': {'id': '8650', 'name': 'Liverpool', 'score': 1},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-09-30T16:30:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '2 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193526',
#   'pageUrl': '/matches/brentford-vs-nottingham-forest/3crchb#4193526',
#   'opponent': {'id': '10203', 'name': 'Nottm Forest', 'score': 1},
#   'home': {'id': '10203', 'name': 'Nottm Forest', 'score': 1},
#   'away': {'id': '9937', 'name': 'Brentford', 'score': 1},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-10-01T13:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '1 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193523',
#   'pageUrl': '/matches/chelsea-vs-fulham/2s2omg#4193523',
#   'opponent': {'id': '9879', 'name': 'Fulham', 'score': 0},
#   'home': {'id': '9879', 'name': 'Fulham', 'score': 0},
#   'away': {'id': '8455', 'name': 'Chelsea', 'score': 2},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-10-02T19:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '0 - 2',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193474',
#   'pageUrl': '/matches/burnley-vs-luton-town/29f34v#4193474',
#   'opponent': {'id': '8346', 'name': 'Luton', 'score': 1},
#   'home': {'id': '8346', 'name': 'Luton', 'score': 1},
#   'away': {'id': '8191', 'name': 'Burnley', 'score': 2},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-10-03T18:30:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '1 - 2',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193536',
#   'pageUrl': '/matches/luton-town-vs-tottenham-hotspur/2dcrvo#4193536',
#   'opponent': {'id': '8346', 'name': 'Luton', 'score': 0},
#   'home': {'id': '8346', 'name': 'Luton', 'score': 0},
#   'away': {'id': '8586', 'name': 'Tottenham', 'score': 1},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-10-07T11:30:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '0 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193532',
#   'pageUrl': '/matches/burnley-vs-chelsea/2ahuos#4193532',
#   'opponent': {'id': '8191', 'name': 'Burnley', 'score': 1},
#   'home': {'id': '8191', 'name': 'Burnley', 'score': 1},
#   'away': {'id': '8455', 'name': 'Chelsea', 'score': 4},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-10-07T14:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '1 - 4',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193534',
#   'pageUrl': '/matches/everton-vs-afc-bournemouth/2hkv2h#4193534',
#   'opponent': {'id': '8668', 'name': 'Everton', 'score': 3},
#   'home': {'id': '8668', 'name': 'Everton', 'score': 3},
#   'away': {'id': '8678', 'name': 'Bournemouth', 'score': 0},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-10-07T14:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '3 - 0',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193535',
#   'pageUrl': '/matches/sheffield-united-vs-fulham/2uai23#4193535',
#   'opponent': {'id': '9879', 'name': 'Fulham', 'score': 3},
#   'home': {'id': '9879', 'name': 'Fulham', 'score': 3},
#   'away': {'id': '8657', 'name': 'Sheff Utd', 'score': 1},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-10-07T14:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '3 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193537',
#   'pageUrl': '/matches/brentford-vs-manchester-united/3dfzjk#4193537',
#   'opponent': {'id': '10260', 'name': 'Man United', 'score': 2},
#   'home': {'id': '10260', 'name': 'Man United', 'score': 2},
#   'away': {'id': '9937', 'name': 'Brentford', 'score': 1},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': False,
#   'tournament': {},
#   'status': {'utcTime': '2023-10-07T14:00:00.000Z',
#    'finished': True,
#    'started': True,
#    'cancelled': False,
#    'scoreStr': '2 - 1',
#    'reason': {'short': 'FT',
#     'shortKey': 'fulltime_short',
#     'long': 'Full-Time',
#     'longKey': 'finished'}}},
#  {'id': '4193533',
#   'pageUrl': '/matches/crystal-palace-vs-nottingham-forest/3bfk5h#4193533',
#   'opponent': {'id': '9826', 'name': 'Crystal Palace', 'score': 0},
# ...
#   'away': {'id': '8657', 'name': 'Sheff Utd'},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': True,
#   'tournament': {},
#   'status': {'utcTime': '2024-04-27T14:00:00.000Z',
#    'started': False,
#    'cancelled': False,
#    'finished': False}},
#  {'id': '4193877',
#   'pageUrl': '/matches/manchester-city-vs-nottingham-forest/2vni1q#4193877',
#   'opponent': {'id': '10203', 'name': 'Nottm Forest'},
#   'home': {'id': '10203', 'name': 'Nottm Forest'},
#   'away': {'id': '8456', 'name': 'Man City'},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': True,
#   'tournament': {},
#   'status': {'utcTime': '2024-04-27T14:00:00.000Z',
#    'started': False,
#    'cancelled': False,
#    'finished': False}},
#  {'id': '4193878',
#   'pageUrl': '/matches/tottenham-hotspur-vs-arsenal/2sx06r#4193878',
#   'opponent': {'id': '8586', 'name': 'Tottenham'},
#   'home': {'id': '8586', 'name': 'Tottenham'},
#   'away': {'id': '9825', 'name': 'Arsenal'},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': True,
#   'tournament': {},
#   'status': {'utcTime': '2024-04-27T14:00:00.000Z',
#    'started': False,
#    'cancelled': False,
#    'finished': False}},
#  {'id': '4193879',
#   'pageUrl': '/matches/liverpool-vs-west-ham-united/2h59kq#4193879',
#   'opponent': {'id': '8654', 'name': 'West Ham'},
#   'home': {'id': '8654', 'name': 'West Ham'},
#   'away': {'id': '8650', 'name': 'Liverpool'},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': True,
#   'tournament': {},
#   'status': {'utcTime': '2024-04-27T14:00:00.000Z',
#    'started': False,
#    'cancelled': False,
#    'finished': False}},
#  {'id': '4193880',
#   'pageUrl': '/matches/luton-town-vs-wolverhampton-wanderers/2dil18#4193880',
#   'opponent': {'id': '8602', 'name': 'Wolves'},
#   'home': {'id': '8602', 'name': 'Wolves'},
#   'away': {'id': '8346', 'name': 'Luton'},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': True,
#   'tournament': {},
#   'status': {'utcTime': '2024-04-27T14:00:00.000Z',
#    'started': False,
#    'cancelled': False,
#    'finished': False}},
#  {'id': '4193881',
#   'pageUrl': '/matches/afc-bournemouth-vs-arsenal/2txefx#4193881',
#   'opponent': {'id': '9825', 'name': 'Arsenal'},
#   'home': {'id': '9825', 'name': 'Arsenal'},
#   'away': {'id': '8678', 'name': 'Bournemouth'},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': True,
#   'tournament': {},
#   'status': {'utcTime': '2024-05-04T14:00:00.000Z',
#    'started': False,
#    'cancelled': False,
#    'finished': False}},
#  {'id': '4193882',
#   'pageUrl': '/matches/fulham-vs-brentford/38wlut#4193882',
#   'opponent': {'id': '9937', 'name': 'Brentford'},
#   'home': {'id': '9937', 'name': 'Brentford'},
#   'away': {'id': '9879', 'name': 'Fulham'},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': True,
#   'tournament': {},
#   'status': {'utcTime': '2024-05-04T14:00:00.000Z',
#    'started': False,
#    'cancelled': False,
#    'finished': False}},
#  {'id': '4193883',
#   'pageUrl': '/matches/brighton-hove-albion-vs-aston-villa/3gku1s#4193883',
#   'opponent': {'id': '10204', 'name': 'Brighton'},
#   'home': {'id': '10204', 'name': 'Brighton'},
#   'away': {'id': '10252', 'name': 'Aston Villa'},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': True,
#   'tournament': {},
#   'status': {'utcTime': '2024-05-04T14:00:00.000Z',
#    'started': False,
#    'cancelled': False,
#    'finished': False}},
#  {'id': '4193884',
#   'pageUrl': '/matches/burnley-vs-newcastle-united/2td61d#4193884',
#   'opponent': {'id': '8191', 'name': 'Burnley'},
#   'home': {'id': '8191', 'name': 'Burnley'},
#   'away': {'id': '10261', 'name': 'Newcastle'},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': True,
#   'tournament': {},
#   'status': {'utcTime': '2024-05-04T14:00:00.000Z',
#    'started': False,
#    'cancelled': False,
#    'finished': False}},
#  {'id': '4193885',
#   'pageUrl': '/matches/chelsea-vs-west-ham-united/2f5ck5#4193885',
#   'opponent': {'id': '8455', 'name': 'Chelsea'},
#   'home': {'id': '8455', 'name': 'Chelsea'},
#   'away': {'id': '8654', 'name': 'West Ham'},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': True,
#   'tournament': {},
#   'status': {'utcTime': '2024-05-04T14:00:00.000Z',
#    'started': False,
#    'cancelled': False,
#    'finished': False}},
#  {'id': '4193886',
#   'pageUrl': '/matches/crystal-palace-vs-manchester-united/3c42bz#4193886',
#   'opponent': {'id': '9826', 'name': 'Crystal Palace'},
#   'home': {'id': '9826', 'name': 'Crystal Palace'},
#   'away': {'id': '10260', 'name': 'Man United'},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': True,
#   'tournament': {},
#   'status': {'utcTime': '2024-05-04T14:00:00.000Z',
#    'started': False,
#    'cancelled': False,
#    'finished': False}},
#  {'id': '4193887',
#   'pageUrl': '/matches/tottenham-hotspur-vs-liverpool/2gg3ek#4193887',
#   'opponent': {'id': '8650', 'name': 'Liverpool'},
#   'home': {'id': '8650', 'name': 'Liverpool'},
#   'away': {'id': '8586', 'name': 'Tottenham'},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': True,
#   'tournament': {},
#   'status': {'utcTime': '2024-05-04T14:00:00.000Z',
#    'started': False,
#    'cancelled': False,
#    'finished': False}},
#  {'id': '4193888',
#   'pageUrl': '/matches/luton-town-vs-everton/2e6lvt#4193888',
#   'opponent': {'id': '8346', 'name': 'Luton'},
#   'home': {'id': '8346', 'name': 'Luton'},
#   'away': {'id': '8668', 'name': 'Everton'},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': True,
#   'tournament': {},
#   'status': {'utcTime': '2024-05-04T14:00:00.000Z',
#    'started': False,
#    'cancelled': False,
#    'finished': False}},
#  {'id': '4193889',
#   'pageUrl': '/matches/manchester-city-vs-wolverhampton-wanderers/2emo8d#4193889',
#   'opponent': {'id': '8456', 'name': 'Man City'},
#   'home': {'id': '8456', 'name': 'Man City'},
#   'away': {'id': '8602', 'name': 'Wolves'},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': True,
#   'tournament': {},
#   'status': {'utcTime': '2024-05-04T14:00:00.000Z',
#    'started': False,
#    'cancelled': False,
#    'finished': False}},
#  {'id': '4193890',
#   'pageUrl': '/matches/sheffield-united-vs-nottingham-forest/2xwbqn#4193890',
#   'opponent': {'id': '8657', 'name': 'Sheff Utd'},
#   'home': {'id': '8657', 'name': 'Sheff Utd'},
#   'away': {'id': '10203', 'name': 'Nottm Forest'},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': True,
#   'tournament': {},
#   'status': {'utcTime': '2024-05-04T14:00:00.000Z',
#    'started': False,
#    'cancelled': False,
#    'finished': False}},
#  {'id': '4193891',
#   'pageUrl': '/matches/afc-bournemouth-vs-brentford/2v5yfp#4193891',
#   'opponent': {'id': '8678', 'name': 'Bournemouth'},
#   'home': {'id': '8678', 'name': 'Bournemouth'},
#   'away': {'id': '9937', 'name': 'Brentford'},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': True,
#   'tournament': {},
#   'status': {'utcTime': '2024-05-11T14:00:00.000Z',
#    'started': False,
#    'cancelled': False,
#    'finished': False}},
#  {'id': '4193892',
#   'pageUrl': '/matches/liverpool-vs-aston-villa/2ydbmv#4193892',
#   'opponent': {'id': '10252', 'name': 'Aston Villa'},
#   'home': {'id': '10252', 'name': 'Aston Villa'},
#   'away': {'id': '8650', 'name': 'Liverpool'},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': True,
#   'tournament': {},
#   'status': {'utcTime': '2024-05-11T14:00:00.000Z',
#    'started': False,
#    'cancelled': False,
#    'finished': False}},
#  {'id': '4193893',
#   'pageUrl': '/matches/sheffield-united-vs-everton/2hd25j#4193893',
#   'opponent': {'id': '8668', 'name': 'Everton'},
#   'home': {'id': '8668', 'name': 'Everton'},
#   'away': {'id': '8657', 'name': 'Sheff Utd'},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': True,
#   'tournament': {},
#   'status': {'utcTime': '2024-05-11T14:00:00.000Z',
#    'started': False,
#    'cancelled': False,
#    'finished': False}},
#  {'id': '4193894',
#   'pageUrl': '/matches/manchester-city-vs-fulham/2s32rr#4193894',
#   'opponent': {'id': '9879', 'name': 'Fulham'},
#   'home': {'id': '9879', 'name': 'Fulham'},
#   'away': {'id': '8456', 'name': 'Man City'},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': True,
#   'tournament': {},
#   'status': {'utcTime': '2024-05-11T14:00:00.000Z',
#    'started': False,
#    'cancelled': False,
#    'finished': False}},
#  {'id': '4193895',
#   'pageUrl': '/matches/arsenal-vs-manchester-united/3c3mu0#4193895',
#   'opponent': {'id': '10260', 'name': 'Man United'},
#   'home': {'id': '10260', 'name': 'Man United'},
#   'away': {'id': '9825', 'name': 'Arsenal'},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': True,
#   'tournament': {},
#   'status': {'utcTime': '2024-05-11T14:00:00.000Z',
#    'started': False,
#    'cancelled': False,
#    'finished': False}},
#  {'id': '4193896',
#   'pageUrl': '/matches/brighton-hove-albion-vs-newcastle-united/3gos5a#4193896',
#   'opponent': {'id': '10261', 'name': 'Newcastle'},
#   'home': {'id': '10261', 'name': 'Newcastle'},
#   'away': {'id': '10204', 'name': 'Brighton'},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': True,
#   'tournament': {},
#   'status': {'utcTime': '2024-05-11T14:00:00.000Z',
#    'started': False,
#    'cancelled': False,
#    'finished': False}},
#  {'id': '4193897',
#   'pageUrl': '/matches/chelsea-vs-nottingham-forest/2vn3ne#4193897',
#   'opponent': {'id': '10203', 'name': 'Nottm Forest'},
#   'home': {'id': '10203', 'name': 'Nottm Forest'},
#   'away': {'id': '8455', 'name': 'Chelsea'},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': True,
#   'tournament': {},
#   'status': {'utcTime': '2024-05-11T14:00:00.000Z',
#    'started': False,
#    'cancelled': False,
#    'finished': False}},
#  {'id': '4193898',
#   'pageUrl': '/matches/burnley-vs-tottenham-hotspur/2bss1j#4193898',
#   'opponent': {'id': '8586', 'name': 'Tottenham'},
#   'home': {'id': '8586', 'name': 'Tottenham'},
#   'away': {'id': '8191', 'name': 'Burnley'},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': True,
#   'tournament': {},
#   'status': {'utcTime': '2024-05-11T14:00:00.000Z',
#    'started': False,
#    'cancelled': False,
#    'finished': False}},
#  {'id': '4193899',
#   'pageUrl': '/matches/luton-town-vs-west-ham-united/2e1i5e#4193899',
#   'opponent': {'id': '8654', 'name': 'West Ham'},
#   'home': {'id': '8654', 'name': 'West Ham'},
#   'away': {'id': '8346', 'name': 'Luton'},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': True,
#   'tournament': {},
#   'status': {'utcTime': '2024-05-11T14:00:00.000Z',
#    'started': False,
#    'cancelled': False,
#    'finished': False}},
#  {'id': '4193900',
#   'pageUrl': '/matches/wolverhampton-wanderers-vs-crystal-palace/2t3pt4#4193900',
#   'opponent': {'id': '8602', 'name': 'Wolves'},
#   'home': {'id': '8602', 'name': 'Wolves'},
#   'away': {'id': '9826', 'name': 'Crystal Palace'},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': True,
#   'tournament': {},
#   'status': {'utcTime': '2024-05-11T14:00:00.000Z',
#    'started': False,
#    'cancelled': False,
#    'finished': False}},
#  {'id': '4193901',
#   'pageUrl': '/matches/everton-vs-arsenal/2ttfpg#4193901',
#   'opponent': {'id': '9825', 'name': 'Arsenal'},
#   'home': {'id': '9825', 'name': 'Arsenal'},
#   'away': {'id': '8668', 'name': 'Everton'},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': True,
#   'tournament': {},
#   'status': {'utcTime': '2024-05-19T15:00:00.000Z',
#    'started': False,
#    'cancelled': False,
#    'finished': False}},
#  {'id': '4193902',
#   'pageUrl': '/matches/brentford-vs-newcastle-united/3dgf4m#4193902',
#   'opponent': {'id': '9937', 'name': 'Brentford'},
#   'home': {'id': '9937', 'name': 'Brentford'},
#   'away': {'id': '10261', 'name': 'Newcastle'},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': True,
#   'tournament': {},
#   'status': {'utcTime': '2024-05-19T15:00:00.000Z',
#    'started': False,
#    'cancelled': False,
#    'finished': False}},
#  {'id': '4193903',
#   'pageUrl': '/matches/brighton-hove-albion-vs-manchester-united/3goccs#4193903',
#   'opponent': {'id': '10204', 'name': 'Brighton'},
#   'home': {'id': '10204', 'name': 'Brighton'},
#   'away': {'id': '10260', 'name': 'Man United'},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': True,
#   'tournament': {},
#   'status': {'utcTime': '2024-05-19T15:00:00.000Z',
#    'started': False,
#    'cancelled': False,
#    'finished': False}},
#  {'id': '4193904',
#   'pageUrl': '/matches/burnley-vs-nottingham-forest/2sq9j2#4193904',
#   'opponent': {'id': '8191', 'name': 'Burnley'},
#   'home': {'id': '8191', 'name': 'Burnley'},
#   'away': {'id': '10203', 'name': 'Nottm Forest'},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': True,
#   'tournament': {},
#   'status': {'utcTime': '2024-05-19T15:00:00.000Z',
#    'started': False,
#    'cancelled': False,
#    'finished': False}},
#  {'id': '4193905',
#   'pageUrl': '/matches/chelsea-vs-afc-bournemouth/2fe5n5#4193905',
#   'opponent': {'id': '8455', 'name': 'Chelsea'},
#   'home': {'id': '8455', 'name': 'Chelsea'},
#   'away': {'id': '8678', 'name': 'Bournemouth'},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': True,
#   'tournament': {},
#   'status': {'utcTime': '2024-05-19T15:00:00.000Z',
#    'started': False,
#    'cancelled': False,
#    'finished': False}},
#  {'id': '4193906',
#   'pageUrl': '/matches/crystal-palace-vs-aston-villa/3c0md7#4193906',
#   'opponent': {'id': '9826', 'name': 'Crystal Palace'},
#   'home': {'id': '9826', 'name': 'Crystal Palace'},
#   'away': {'id': '10252', 'name': 'Aston Villa'},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': True,
#   'tournament': {},
#   'status': {'utcTime': '2024-05-19T15:00:00.000Z',
#    'started': False,
#    'cancelled': False,
#    'finished': False}},
#  {'id': '4193907',
#   'pageUrl': '/matches/wolverhampton-wanderers-vs-liverpool/2gm0as#4193907',
#   'opponent': {'id': '8650', 'name': 'Liverpool'},
#   'home': {'id': '8650', 'name': 'Liverpool'},
#   'away': {'id': '8602', 'name': 'Wolves'},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': True,
#   'tournament': {},
#   'status': {'utcTime': '2024-05-19T15:00:00.000Z',
#    'started': False,
#    'cancelled': False,
#    'finished': False}},
#  {'id': '4193908',
#   'pageUrl': '/matches/luton-town-vs-fulham/2qvz6o#4193908',
#   'opponent': {'id': '8346', 'name': 'Luton'},
#   'home': {'id': '8346', 'name': 'Luton'},
#   'away': {'id': '9879', 'name': 'Fulham'},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': True,
#   'tournament': {},
#   'status': {'utcTime': '2024-05-19T15:00:00.000Z',
#    'started': False,
#    'cancelled': False,
#    'finished': False}},
#  {'id': '4193909',
#   'pageUrl': '/matches/manchester-city-vs-west-ham-united/2f5prf#4193909',
#   'opponent': {'id': '8456', 'name': 'Man City'},
#   'home': {'id': '8456', 'name': 'Man City'},
#   'away': {'id': '8654', 'name': 'West Ham'},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': True,
#   'tournament': {},
#   'status': {'utcTime': '2024-05-19T15:00:00.000Z',
#    'started': False,
#    'cancelled': False,
#    'finished': False}},
#  {'id': '4193910',
#   'pageUrl': '/matches/tottenham-hotspur-vs-sheffield-united/2gioiz#4193910',
#   'opponent': {'id': '8657', 'name': 'Sheff Utd'},
#   'home': {'id': '8657', 'name': 'Sheff Utd'},
#   'away': {'id': '8586', 'name': 'Tottenham'},
#   'displayTournament': True,
#   'lnameArr': ['A', ' | undefined'],
#   'notStarted': True,
#   'tournament': {},
#   'status': {'utcTime': '2024-05-19T15:00:00.000Z',
#    'started': False,
#    'cancelled': False,
#    'finished': False}}]
